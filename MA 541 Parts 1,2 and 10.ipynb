# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#reading the data
data = pd.read_csv('C:/Users/saram/OneDrive/Desktop/Sara Mathews/Stevens Institute of Technology/MA 541/group project/data.csv')
data.head()
# Out:
#    Close_ETF       oil      gold       JPM
# 0  97.349998  0.039242  0.004668  0.032258
# 1  97.750000  0.001953 -0.001366 -0.002948
# 2  99.160004 -0.031514 -0.007937  0.025724
# 3  99.650002  0.034552  0.014621  0.011819
# 4  99.260002  0.013619 -0.011419  0.000855

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Close_ETF  1000 non-null   float64
#  1   oil        1000 non-null   float64
#  2   gold       1000 non-null   float64
#  3   JPM        1000 non-null   float64
# dtypes: float64(4)
# memory usage: 31.4 KB

# %% [markdown]
# ## Part 1
#
# ### The data includes four columns: the daily ETF return, the daily relative change in the price of crude oil, the daily relative change in the gold price and the daily return of the JP Morgan Chase & Co stock. The sample size is 1000.

# %%
data
# Out:
#       Close_ETF       oil      gold       JPM
# 0     97.349998  0.039242  0.004668  0.032258
# 1     97.750000  0.001953 -0.001366 -0.002948
# 2     99.160004 -0.031514 -0.007937  0.025724
# 3     99.650002  0.034552  0.014621  0.011819
# 4     99.260002  0.013619 -0.011419  0.000855
# ..          ...       ...       ...       ...
# 995  150.570007  0.009752  0.004634  0.003859
# 996  151.600006 -0.009341 -0.015325  0.018259
# 997  151.300003  0.036120 -0.006195 -0.007928
# 998  152.619995  0.001542  0.005778 -0.000381
# 999  152.539993  0.020330  0.001965  0.000381
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### Find below the sample mean and standard deviation for each random variable

# %%
data.describe()
# Out:
#          Close_ETF          oil         gold          JPM
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean    121.152960     0.001030     0.000663     0.000530
# std      12.569790     0.021093     0.011289     0.011017
# min      96.419998    -0.116533    -0.065805    -0.048217
# 25%     112.580002    -0.012461    -0.004816    -0.005538
# 50%     120.150002     0.001243     0.001030     0.000386
# 75%     128.687497     0.014278     0.007482     0.006966
# max     152.619995     0.087726     0.042199     0.057480

# %%
np.corrcoef(data.Close_ETF, data.oil)
# Out:
# array([[ 1.        , -0.00904484],
#        [-0.00904484,  1.        ]])

# %%
np.corrcoef(data.Close_ETF,data.gold)
# Out:
# array([[1.        , 0.02299557],
#        [0.02299557, 1.        ]])

# %%
np.corrcoef(data.Close_ETF,data.JPM)
# Out:
# array([[1.        , 0.03680706],
#        [0.03680706, 1.        ]])

# %%
np.corrcoef(data.oil,data.gold)
# Out:
# array([[1.        , 0.23565037],
#        [0.23565037, 1.        ]])

# %%
np.corrcoef(data.oil,data.JPM)
# Out:
# array([[ 1.        , -0.12084893],
#        [-0.12084893,  1.        ]])

# %%
np.corrcoef(data.gold,data.JPM)
# Out:
# array([[1.        , 0.10016984],
#        [0.10016984, 1.        ]])

# %% [markdown]
# ## Part 2
# ## Data description
# ### 1. Histograms

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
data['Close_ETF'].hist(bins = 25)
plt.title('Histogram for Close_ETF')
# Out:
# Text(0.5, 1.0, 'Histogram for Close_ETF')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
data['oil'].hist(bins = 200)
plt.title('Histogram for Oil')
# Out:
# Text(0.5, 1.0, 'Histogram for Oil')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
data['gold'].hist(bins = 200)
plt.title('Histogram for Gold')
# Out:
# Text(0.5, 1.0, 'Histogram for Gold')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
data['JPM'].hist(bins = 200)
plt.title('Histogram for JPM')
# Out:
# Text(0.5, 1.0, 'Histogram for JPM')

# %% [markdown]
# ### 2. Time series plot for each column

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
data['Close_ETF'].plot()
plt.title('Time Series for Close_ETF')
plt.xlabel('Days')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
data['gold'].plot()
plt.title('Time Series for Gold')
plt.xlabel('Days')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
data['oil'].plot()
plt.title('Time Series for Oil')
plt.xlabel('Days')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
data['JPM'].plot()
plt.title('Time Series for JPM')
plt.xlabel('Days')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')

# %% [markdown]
# ### 3. Time series plot for all the four columns

# %%
data.plot(figsize = (15,10))

# %% [markdown]
# ### 4. Scatter plots presenting relationships between data

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
plt.scatter(data.Close_ETF,data.oil)
plt.title('Scatter Plot of Close_ETF versus Oil')
plt.xlabel('ETF')
plt.ylabel('Oil')
# Out:
# Text(0, 0.5, 'Oil')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
plt.scatter(data.Close_ETF,data.gold)
plt.title('Scatter Plot of Close_ETF versus Gold')
plt.xlabel('ETF')
plt.ylabel('gold')
# Out:
# Text(0, 0.5, 'gold')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.5, 8.5)
plt.scatter(data.Close_ETF,data.JPM)
plt.title('Scatter Plot of Close_ETF versus JPM')
plt.xlabel('ETF')
plt.ylabel('JPM')
# Out:
# Text(0, 0.5, 'JPM')

# %% [markdown]
# # Part 10

# %%
from sklearn import linear_model
import statsmodels.api as sm
X = data[['gold','oil']]
Y = data['Close_ETF']

# %%
regr = linear_model.LinearRegression()
regr.fit(X, Y)
# Out:
# LinearRegression()

# %%
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  121.14272529623004
# Coefficients:
#  [29.62259192 -9.12610011]

# %%
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
predictions = model.predict(X)

# %%
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Close_ETF   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.3743
# Date:                Sat, 28 Nov 2020   Prob (F-statistic):              0.688
# Time:                        22:06:39   Log-Likelihood:                -3949.4
# No. Observations:                1000   AIC:                             7905.
# Df Residuals:                     997   BIC:                             7919.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        121.1427      0.399    303.856      0.000     120.360     121.925
# gold          29.6226     36.272      0.817      0.414     -41.555     100.800
# oil           -9.1261     19.413     -0.470      0.638     -47.221      28.968
# ==============================================================================
# Omnibus:                       26.565   Durbin-Watson:                   0.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.981
# Skew:                           0.306   Prob(JB):                     1.02e-05
# Kurtosis:                       2.579   Cond. No.                         92.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import seaborn as sns 
import statsmodels.stats.api as sms
sns.set_style('darkgrid')
sns.mpl.rcParams['figure.figsize'] = (15.0, 9.0)

# %%
def linearity_test(model_1, y):
    fitted_vals = model_1.predict()
    resids = model_1.resid

    fig, ax = plt.subplots(1,2)
    
    sns.regplot(x=fitted_vals, y=y, lowess=True, ax=ax[0], line_kws={'color': 'red'})
    ax[0].set_title('Observed vs. Predicted Values', fontsize=16)
    ax[0].set(xlabel='Predicted', ylabel='Observed')

    sns.regplot(x=fitted_vals, y=resids, lowess=True, ax=ax[1], line_kws={'color': 'red'})
    ax[1].set_title('Residuals vs. Predicted Values', fontsize=16)
    ax[1].set(xlabel='Predicted', ylabel='Residuals')
    print(resids)
    
linearity_test(model, Y)
# Out:
# 0     -23.572870
# 1     -23.334422
# 2     -22.035221
# 3     -21.610500
# 4     -21.420170
#          ...
# 995    29.379017
# 996    30.826000
# 997    30.670427
# 998    31.320196
# 999    31.524582
# Length: 1000, dtype: float64

# %%
model.resid.mean()
# Out:
# -5.022116056352388e-14

# %% [markdown]
# ### The residual mean is zero.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):
    
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
X = data.iloc[:,:-1]
calc_vif(X)
# Out:
#    variables       VIF
# 0  Close_ETF  1.004874
# 1        oil  1.061195
# 2       gold  1.062705

# %% [markdown]
# ### Multi-collinearity can be determined by the Variance Inflation Factor. For a model where none of the variables are correlated, the value of the factor will be 1. Here, VIF=1, therefore there is no correlation between the independent variables and the other variables

# %%
def homoscedasticity_test(model_1):
    
    fitted_vals = model_1.predict()
    resids = model_1.resid
    resids_standardized = model_1.get_influence().resid_studentized_internal

    fig, ax = plt.subplots(1,2)

    sns.regplot(x=fitted_vals, y=resids, lowess=True, ax=ax[0], line_kws={'color': 'red'})
    ax[0].set_title('Residuals vs Fitted', fontsize=16)
    ax[0].set(xlabel='Fitted Values', ylabel='Residuals')

    sns.regplot(x=fitted_vals, y=np.sqrt(np.abs(resids_standardized)), lowess=True, ax=ax[1], line_kws={'color': 'red'})
    ax[1].set_title('Scale-Location', fontsize=16)
    ax[1].set(xlabel='Fitted Values', ylabel='sqrt(abs(Residuals))')

    bp_test = pd.DataFrame(sms.het_breuschpagan(resids, model.model.exog), 
                           columns=['value'],
                           index=['Lagrange multiplier statistic', 'p-value', 'f-value', 'f p-value'])

    gq_test = pd.DataFrame(sms.het_goldfeldquandt(resids, model.model.exog)[:-1],
                           columns=['value'],
                           index=['F statistic', 'p-value'])

    print('\n Breusch-Pagan test ----')
    print(bp_test)
    print('\n Goldfeld-Quandt test ----')
    print(gq_test)
    print('\n Residuals plots ----')

homoscedasticity_test(model)
# Out:
#  Breusch-Pagan test ----
#                                   value
# Lagrange multiplier statistic  0.093360
# p-value                        0.954393
# f-value                        0.046544
# f p-value                      0.954525
#
#  Goldfeld-Quandt test ----
#                     value
# F statistic  1.738851e+00
# p-value      4.536050e-10
#
#  Residuals plots ----

# %%
from statsmodels.compat import lzip
names = ['Lagrange multiplier statistic', 'p-value',
        'f-value', 'f p-value']
test = sms.het_breuschpagan(model.resid, model.model.exog)

lzip(names, test)
# Out:
# [('Lagrange multiplier statistic', 0.09335952400713055),
#  ('p-value', 0.9543929815541857),
#  ('f-value', 0.04654406804960322),
#  ('f p-value', 0.9545245696237531)]

# %% [markdown]
# ### The p-value is not less than 0.05, therefore, by Breusch Pagan test, homoscedasticity is present, ie, the variance is equal.

# %%
from scipy import stats

def normality_of_residuals_test(model):
   
    sm.ProbPlot(model.resid).qqplot(line='s');
    plt.title('Q-Q plot');

    jb = stats.jarque_bera(model.resid)
    sw = stats.shapiro(model.resid)
    ad = stats.anderson(model.resid, dist='norm')
    ks = stats.kstest(model.resid, 'norm')
    
    print(f'Jarque-Bera test ---- statistic: {jb[0]:.4f}, p-value: {jb[1]}')
    print(f'Shapiro-Wilk test ---- statistic: {sw[0]:.4f}, p-value: {sw[1]:.4f}')
    print(f'Kolmogorov-Smirnov test ---- statistic: {ks.statistic:.4f}, p-value: {ks.pvalue:.4f}')
    print(f'Anderson-Darling test ---- statistic: {ad.statistic:.4f}, 5% critical value: {ad.critical_values[2]:.4f}')
    
normality_of_residuals_test(model)
# Out:
# Jarque-Bera test ---- statistic: 22.9812, p-value: 1.0225921782902603e-05
# Shapiro-Wilk test ---- statistic: 0.9797, p-value: 0.0000
# Kolmogorov-Smirnov test ---- statistic: 0.4407, p-value: 0.0000
# Anderson-Darling test ---- statistic: 4.6274, 5% critical value: 0.7840

# %% [markdown]
# ### As the AD statistic is greater than the critical value at 5% level of significance, the assumption that the data comes from a normal distribution is not satisfied.
