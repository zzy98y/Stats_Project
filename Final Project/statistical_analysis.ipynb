# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline
import scipy.stats as stats
import math

# %%
# load the data 
df = pd.read_csv('data.csv')
df.head()
# Out:
#    Close_ETF       oil      gold       JPM
# 0  97.349998  0.039242  0.004668  0.032258
# 1  97.750000  0.001953 -0.001366 -0.002948
# 2  99.160004 -0.031514 -0.007937  0.025724
# 3  99.650002  0.034552  0.014621  0.011819
# 4  99.260002  0.013619 -0.011419  0.000855

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Close_ETF  1000 non-null   float64
#  1   oil        1000 non-null   float64
#  2   gold       1000 non-null   float64
#  3   JPM        1000 non-null   float64
# dtypes: float64(4)
# memory usage: 31.4 KB

# %%
list1 = []
list2 = []
list3 = []
for i in range(len(df['Close_ETF'])): 
    a = df['Close_ETF'][i] + df['oil'][i]
    b = df['Close_ETF'][i] + df['gold'][i]
    c = df['Close_ETF'][i] + df['JPM'][i]
    list1.append(a)
    list2.append(b)
    list3.append(c)

# %%
df['oil_current'] = list1
df['gold_current'] = list2
df['JPM_current'] = list3

# %%
df
# Out:
#       Close_ETF       oil      gold       JPM  oil_current  gold_current  \
# 0     97.349998  0.039242  0.004668  0.032258    97.389240     97.354666
# 1     97.750000  0.001953 -0.001366 -0.002948    97.751953     97.748634
# 2     99.160004 -0.031514 -0.007937  0.025724    99.128490     99.152067
# 3     99.650002  0.034552  0.014621  0.011819    99.684554     99.664623
# 4     99.260002  0.013619 -0.011419  0.000855    99.273621     99.248583
# ..          ...       ...       ...       ...          ...           ...
# 995  150.570007  0.009752  0.004634  0.003859   150.579759    150.574641
# 996  151.600006 -0.009341 -0.015325  0.018259   151.590665    151.584681
# 997  151.300003  0.036120 -0.006195 -0.007928   151.336123    151.293808
# 998  152.619995  0.001542  0.005778 -0.000381   152.621537    152.625773
# 999  152.539993  0.020330  0.001965  0.000381   152.560323    152.541958
#
#      JPM_current
# 0      97.382256
# 1      97.747052
# 2      99.185728
# 3      99.661821
# ...

# %%
df = df.drop(columns = ['oil','gold','JPM'])

# %%
df
# Out:
#       Close_ETF  oil_current  gold_current  JPM_current
# 0     97.349998    97.389240     97.354666    97.382256
# 1     97.750000    97.751953     97.748634    97.747052
# 2     99.160004    99.128490     99.152067    99.185728
# 3     99.650002    99.684554     99.664623    99.661821
# 4     99.260002    99.273621     99.248583    99.260857
# ..          ...          ...           ...          ...
# 995  150.570007   150.579759    150.574641   150.573866
# 996  151.600006   151.590665    151.584681   151.618265
# 997  151.300003   151.336123    151.293808   151.292075
# 998  152.619995   152.621537    152.625773   152.619614
# 999  152.539993   152.560323    152.541958   152.540374
#
# [1000 rows x 4 columns]

# %% [markdown]
# # Part I

# %%
df.describe()
# Out:
#          Close_ETF  oil_current  gold_current  JPM_current
# count  1000.000000  1000.000000   1000.000000  1000.000000
# mean    121.152960   121.153990    121.153623   121.153490
# std      12.569790    12.569617     12.570055    12.570201
# min      96.419998    96.436979     96.422804    96.391240
# 25%     112.580002   112.575975    112.572209   112.582608
# 50%     120.150002   120.161518    120.146369   120.151980
# 75%     128.687497   128.686736    128.699829   128.688664
# max     152.619995   152.621537    152.625773   152.619614

# %%
np.corrcoef(df.Close_ETF,df.oil_current)
# Out:
# array([[1.        , 0.99999859],
#        [0.99999859, 1.        ]])

# %%
np.corrcoef(df.Close_ETF,df.gold_current)
# Out:
# array([[1.       , 0.9999996],
#        [0.9999996, 1.       ]])

# %%
np.corrcoef(df.Close_ETF,df.JPM_current)
# Out:
# array([[1.        , 0.99999962],
#        [0.99999962, 1.        ]])

# %%
np.corrcoef(df.oil_current,df.gold_current)
# Out:
# array([[1.        , 0.99999854],
#        [0.99999854, 1.        ]])

# %%
np.corrcoef(df.oil_current,df.JPM_current)
# Out:
# array([[1.        , 0.99999803],
#        [0.99999803, 1.        ]])

# %%
np.corrcoef(df.gold_current,df.JPM_current)
# Out:
# array([[1.        , 0.99999929],
#        [0.99999929, 1.        ]])

# %% [markdown]
# # Part II

# %%
# histogram for Close_ETF 
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
df['Close_ETF'].hist()
plt.title('Histogram for Close_ETF')
# Out:
# Text(0.5, 1.0, 'Histogram for Close_ETF')

# %%
# histogram for oil 
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
df['oil_current'].hist()
plt.title('Histogram for oil')
# Out:
# Text(0.5, 1.0, 'Histogram for oil')

# %%
# histogram for gold 
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
df['gold_current'].hist()
plt.title('Histogram for gold')
# Out:
# Text(0.5, 1.0, 'Histogram for gold')

# %%
# histogram for JPM 
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
df['JPM_current'].hist()
plt.title('Histogram for JPM')
# Out:
# Text(0.5, 1.0, 'Histogram for JPM')

# %%
# Time series for Close ETF 
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
df['Close_ETF'].plot()
plt.title('Time Series for Close_ETF')
# Out:
# Text(0.5, 1.0, 'Time Series for Close_ETF')

# %%
# Time Series for oil 
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
df['oil_current'].plot()
plt.title('Time Series for oil')
# Out:
# Text(0.5, 1.0, 'Time Series for oil')

# %%
# Time Series for gold 
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
df['gold_current'].plot()
plt.title('Time Series for gold')
# Out:
# Text(0.5, 1.0, 'Time Series for gold')

# %%
# Time Series for JPM 
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
df['JPM_current'].plot()
plt.title('Time Series for JPM')
# Out:
# Text(0.5, 1.0, 'Time Series for JPM')

# %%
# Time Series for all 
df.plot(figsize = (15,10))

# %%
# scatter between ETF and oil 
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.scatter(df.Close_ETF,df.oil_current)
plt.title('Scatter Plot for Close_ETF and Oil')
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Close_ETF and Oil')

# %%
# scatter between ETF and gold 
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.scatter(df.Close_ETF,df.gold_current)
plt.title('Scatter Plot for Close_ETF and gold')
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Close_ETF and gold')

# %%
# scatter between ETF and JPM
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.scatter(df.Close_ETF,df.JPM_current)
plt.title('Scatter Plot for Close_ETF and JPM ')
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Close_ETF and JPM ')

# %% [markdown]
# # Part III

# %% [markdown]
# > I believe the all four columns are normal, and I am going to test it below to see if it's true.

# %%
# column Close_ETF 
stats.skew(df.Close_ETF)
# Out:
# 0.3059866902884341

# %%
W,P = stats.shapiro(df.Close_ETF)
print(W,P)
# Out:
# 0.9795047640800476 1.1655147680311728e-10

# %% [markdown]
# Since it's p value is less than 0.05 (the assumed significance level), therefore it's not normal, and it has a skewness of 0.305.

# %%
# column oil 
stats.skew(df.oil_current)
# Out:
# 0.3060848534137424

# %%
W,P = stats.shapiro(df.oil_current)
print(W,P)
# Out:
# 0.9794955253601074 1.1571098940121871e-10

# %% [markdown]
# Since it's p value is less than 0.05 (the assumed significance level), therefore it's not normal, and it has a skewness of 0.306.

# %%
# column gold 
stats.skew(df.gold_current)
# Out:
# 0.30601147872648604

# %%
W,P = stats.shapiro(df.gold_current)
print(W,P)
# Out:
# 0.9795032739639282 1.16418485962555e-10

# %% [markdown]
# Since it's p value is less than 0.05 (the assumed significance level), therefore it's not normal, and it has a skewness of 0.306.

# %%
# column JPM 
stats.skew(df.JPM_current)
# Out:
# 0.3060112018735435

# %%
W,P = stats.shapiro(df.JPM_current)
print(W,P)
# Out:
# 0.9795289039611816 1.1878112382568418e-10

# %% [markdown]
# Since it's p value is less than 0.05 (the assumed significance level), therefore it's not normal, and it has a skewness of 0.306.

# %% [markdown]
# # Part IV

# %%
df['Close_ETF'].mean()
# Out:
# 121.152960012

# %%
df['Close_ETF'].std()
# Out:
# 12.569790313110744

# %% [markdown]
# ### Case I: divide into 20 groups with 50 in each group sequentially

# %%
df['group'] = pd.cut(df['Close_ETF'],bins = 20, labels = False)

# %%
mean = []
for i in range(20):
    mu = df[df['group'] == i]['Close_ETF'].mean()
    mean.append(mu)

# %%
df_mean = pd.DataFrame({'Mean':mean})

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
df_mean['Mean'].hist()
plt.title('Histogram for Sample Mean with sample 50')
# Out:
# Text(0.5, 1.0, 'Histogram for Sample Mean with sample 50')

# %% [markdown]
# The distribution is a skewed distribution and we have no specific name for this type of distribution, and it's definitely not normal.

# %%
df_mean['Mean'].mean()
# Out:
# 124.53343211195133

# %%
df_mean['Mean'].std()
# Out:
# 16.583825365931574

# %%
df['Close_ETF'].std()/math.sqrt(20)
# Out:
# 2.810690560303399

# %% [markdown]
# The sample mean and sample standard deviation both are larger than the population mean and population standard deviation.

# %% [markdown]
# Result from 3 and 4 are not consistent, because the sample is sequential, not random.

# %% [markdown]
# ### Case II: divide into 10 groups with 100 in each group sequentially

# %%
df['group2'] = pd.cut(df['Close_ETF'],bins = 10, labels = False)

# %%
mean2 = []
for i in range(10):
    mu2 = df[df['group'] == i]['Close_ETF'].mean()
    mean2.append(mu2)

# %%
df_mean2 = pd.DataFrame({'Mean':mean2})

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
df_mean2['Mean'].hist()
plt.title('Histogram for Sample Mean with sample 100')
# Out:
# Text(0.5, 1.0, 'Histogram for Sample Mean with sample 100')

# %% [markdown]
# According to the histogram, the distribution is definitely not normal.

# %%
df_mean2['Mean'].mean()
# Out:
# 110.51629069673928

# %%
df_mean2['Mean'].std()
# Out:
# 8.503974289508404

# %%
df['Close_ETF'].std()/math.sqrt(10)
# Out:
# 3.9749167100151

# %% [markdown]
# Sample mean is smaller than population mean and sample standard deviation is larger than population standard deviation.

# %% [markdown]
# Result from 3 and 4 are not consistent, because the group is sequential, not random.

# %% [markdown]
# ### Case III: divide into 50 groups with 20 in each group randomly

# %%
mean3 = []
for i in range(50):
    a = np.random.choice(df.Close_ETF, size = 20, replace = True).mean()
    mean3.append(a)

# %%
df_mean3 = pd.DataFrame({'Mean':mean3})

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
df_mean3['Mean'].hist()
plt.title('Histogram for Sample Mean with sample 20')
# Out:
# Text(0.5, 1.0, 'Histogram for Sample Mean with sample 20')

# %% [markdown]
# The histogram is close to normal, but it's not normal.

# %%
df_mean3['Mean'].mean()
# Out:
# 120.52442991100001

# %%
df_mean3['Mean'].std()
# Out:
# 2.5046425914523653

# %%
df['Close_ETF'].std()/math.sqrt(50)
# Out:
# 1.7776367936987165

# %% [markdown]
# Sample mean is really close to the population mean, and sample standard deviation is greater than population mean.

# %% [markdown]
# Both values are really close, but not consistent with CLT, because each sample size is too small.

# %% [markdown]
# ### Case IV: divide into 10 groups with 100 in each group randomly

# %%
mean4 = []
for i in range(10):
    a = np.random.choice(df.Close_ETF, size = 100, replace = True).mean()
    mean4.append(a)

# %%
df_mean4 = pd.DataFrame({'Mean':mean4})

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
df_mean4['Mean'].hist()
plt.title('Histogram for Sample Mean with sample 100')
# Out:
# Text(0.5, 1.0, 'Histogram for Sample Mean with sample 100')

# %% [markdown]
# It's not normal according to the histogram.

# %%
df_mean4['Mean'].mean()
# Out:
# 121.32487012099998

# %%
df_mean4['Mean'].std()
# Out:
# 1.6149310313656404

# %%
df['Close_ETF'].std()/math.sqrt(10)
# Out:
# 3.9749167100151

# %% [markdown]
# Both Sample mean and sample standard deviation is smaller than population mean and standard deviation.

# %% [markdown]
# There are too few sample mean, though the sample size of each sample is really large, therefore it's does not fit CLT.

# %% [markdown]
# After several trials in this part, I realize I may never be able to get a perfect CLT because the Close_ETF column itself is not normal, so no matter how I sample this column, it will never be normal.

# %%
df = df.drop(columns = ['group','group2'])

# %%
df
# Out:
#       Close_ETF  oil_current  gold_current  JPM_current
# 0     97.349998    97.389240     97.354666    97.382256
# 1     97.750000    97.751953     97.748634    97.747052
# 2     99.160004    99.128490     99.152067    99.185728
# 3     99.650002    99.684554     99.664623    99.661821
# 4     99.260002    99.273621     99.248583    99.260857
# ..          ...          ...           ...          ...
# 995  150.570007   150.579759    150.574641   150.573866
# 996  151.600006   151.590665    151.584681   151.618265
# 997  151.300003   151.336123    151.293808   151.292075
# 998  152.619995   152.621537    152.625773   152.619614
# 999  152.539993   152.560323    152.541958   152.540374
#
# [1000 rows x 4 columns]
